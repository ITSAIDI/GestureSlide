# %% [markdown]
# # Using a VLM

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install langchain-openai==0.2.9

# %% [markdown]
# - Some installation to Use Ollama within Colab

# %% [markdown]
# ## Setup Ollama :

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh

import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# !ollama pull llama3.2-vision:11b
# !ollama list

# %% [markdown]
# ## Test the pipeline

# %% [markdown]
# - A system prompt is used here to customize the behavior of the VLM.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI


system = """
Vous êtes un assistant puissant dans l'extraction d'informations a partir des factures francaises. \n

## Les Informations à extraire sont : \n

- Observer bien la facture et extraire les informations suivantes :  \n

   - Nom_facture : Un String, Le nom et le format(.jpg, .png, .jpeg) de l'image de la facture. \n
   - Fournisseur : Un String, Le nom du fournisseur de la facture. \n
   - date_facture : Un String, La date de la facture. \n
   - num_facture : Un String, L'identifiant de la facture, peut être numérique ou alphanumérique. \n
   - ttc : Un Float, Toutes Taxes Comprises. Il s'agit du prix final total payé par le client. Il inclut le prix Total HT et la Total TVA. \n
   - tt : Un Float, Le total hors taxes de la facture. \n
   - tva : Un Float, Le Total taxes. \n

## Structure de la réponse : \n

- Votre reponse doit être un dictionnaire python.

## Consignes : \n

- Les 3 prix TT,TTC,TVA doivent être numérique sans indication de devise. \n
- le nom de Fournisseur doit être en majuscule. \n
- Ne pas décrire la facture donnée seulement le dictionnaire Python.
"""

# %%
## Prompt Template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        (
            "user",
            [
                 {
                    "type": "text",
                    "text": system,
                },
                {
                    "type": "image_url",
                    "image_url": {"url": "data:image/jpeg;base64,{image_data}"},
                }
            ],
        ),
    ]
)

VLM = ChatOpenAI(
    model="llama3.2-vision:11b",
    #temperature=0,
    api_key='ollama',
    base_url="http://localhost:11434/v1",
)

VLM_Extractor = prompt | VLM

def Run_VLM(InvoiceName,image_data):
    response = VLM_Extractor.invoke({"image_data": image_data,"InvoiceName": InvoiceName})
    return response

# %% [markdown]
# - You find the image used in the Notebooks folder in Github

# %%
import base64

def Image_to_base64(image_path):
    """
    Converts an image file to a Base64 encoded string.

    Args:
        image_path (str): The path to the image file.

    Returns:
        str: The Base64 encoded string of the image.
    """
    try:
        # Open the image file in binary mode
        with open(image_path, "rb") as image_file:
            # Read the file and encode it to Base64
            encoded_string = base64.b64encode(image_file.read()).decode("utf-8")
        return encoded_string
    except Exception as e:
        raise ValueError(f"An error occurred while converting the image: {e}")

# %% [markdown]
# - You find the "2.jpg" image in the Notebooks folde in Github.

# %%
# Example usage
image_path = "2.jpg"
base64_string = Image_to_base64(image_path)
print(base64_string)
# Out:
# ...

# %%
response = Run_VLM("2.jpg",base64_string)
print(response.content)
# Out:
# Dictionnaire Python :
#
# { 'Nom_facture': 'facture_0030524040000075.jpg',
# 'Fournisseur': 'OUTIDIS SARL',
# 'date_facture': '13/01/2023',
# 'num_facture': '0030524040000075',
# 'ttc': 586.80,
# 'tt': 489.00,
# 'tva': 97.8 }

# %% [markdown]
# # Using a Document Parser + LLM

# %% [markdown]
# ## Setup Ollama :

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh

import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# !ollama pull qwen2.5:7b
# !ollama list
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 1s (230 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 56 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pciutils is already the newest version (1:3.7.0-6).
# 0 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠏ pulling manifest
# pulling 2bada8a74506...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   0% ▕▏ 8.8 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   1% ▕▏  38 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   1% ▕▏  54 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   2% ▕▏  91 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   3% ▕▏ 127 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   3% ▕▏ 147 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   4% ▕▏ 180 MB/4.7 GB                  pulling manifest
# pulling 2bada8a74506...   4% ▕▏ 209 MB/4.7 GB  193 MB/s     23spulling manifest
# pulling 2bada8a74506...   5% ▕▏ 218 MB/4.7 GB  193 MB/s     23spulling manifest
# pulling 2bada8a74506...   5% ▕▏ 253 MB/4.7 GB  193 MB/s     22spulling manifest
# pulling 2bada8a74506...   6% ▕▏ 291 MB/4.7 GB  193 MB/s     22spulling manifest
# pulling 2bada8a74506...   7% ▕▏ 321 MB/4.7 GB  193 MB/s     22spulling manifest
# pulling 2bada8a74506...   8% ▕▏ 358 MB/4.7 GB  193 MB/s     22spulling manifest
# pulling 2bada8a74506...   9% ▕▏ 398 MB/4.7 GB  193 MB/s     22spulling manifest
# pulling 2bada8a74506...   9% ▕▏ 420 MB/4.7 GB  193 MB/s     22spulling manifest
# pulling 2bada8a74506...  10% ▕▏ 466 MB/4.7 GB  193 MB/s     21spulling manifest
# pulling 2bada8a74506...  11% ▕▏ 501 MB/4.7 GB  193 MB/s     21spulling manifest
# pulling 2bada8a74506...  11% ▕▏ 512 MB/4.7 GB  256 MB/s     16spulling manifest
# pulling 2bada8a74506...  12% ▕▏ 544 MB/4.7 GB  256 MB/s     16spulling manifest
# pulling 2bada8a74506...  12% ▕▏ 582 MB/4.7 GB  256 MB/s     16spulling manifest
# pulling 2bada8a74506...  13% ▕▏ 596 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  13% ▕▏ 625 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  14% ▕▏ 657 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  14% ▕▏ 671 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  15% ▕▏ 705 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 730 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 730 MB/4.7 GB  256 MB/s     15spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 731 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 733 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 738 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 738 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 739 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 739 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 740 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 740 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 740 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 740 MB/4.7 GB  243 MB/s     16spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 741 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 741 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 742 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 742 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 742 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 743 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 743 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 743 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  16% ▕▏ 743 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  17% ▕▏ 780 MB/4.7 GB  185 MB/s     21spulling manifest
# pulling 2bada8a74506...  17% ▕▏ 817 MB/4.7 GB  185 MB/s     20spulling manifest
# pulling 2bada8a74506...  19% ▕▏ 870 MB/4.7 GB  170 MB/s     22spulling manifest
# pulling 2bada8a74506...  19% ▕▏ 901 MB/4.7 GB  170 MB/s     22spulling manifest
# pulling 2bada8a74506...  20% ▕▏ 915 MB/4.7 GB  170 MB/s     22spulling manifest
# pulling 2bada8a74506...  20% ▕▏ 945 MB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  21% ▕▏ 979 MB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  21% ▕▏ 999 MB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  22% ▕▏ 1.0 GB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  22% ▕▏ 1.1 GB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  23% ▕▏ 1.1 GB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  23% ▕▏ 1.1 GB/4.7 GB  170 MB/s     21spulling manifest
# pulling 2bada8a74506...  24% ▕▏ 1.1 GB/4.7 GB  184 MB/s     19spulling manifest
# pulling 2bada8a74506...  24% ▕▏ 1.1 GB/4.7 GB  184 MB/s     19spulling manifest
# pulling 2bada8a74506...  25% ▕▏ 1.2 GB/4.7 GB  184 MB/s     19spulling manifest
# pulling 2bada8a74506...  25% ▕▏ 1.2 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  26% ▕▏ 1.2 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  26% ▕▏ 1.2 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  27% ▕▏ 1.3 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  27% ▕▏ 1.3 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  28% ▕▏ 1.3 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  28% ▕▏ 1.3 GB/4.7 GB  184 MB/s     18spulling manifest
# pulling 2bada8a74506...  29% ▕▏ 1.4 GB/4.7 GB  193 MB/s     17spulling manifest
# pulling 2bada8a74506...  29% ▕▏ 1.4 GB/4.7 GB  193 MB/s     17spulling manifest
# pulling 2bada8a74506...  95% ▕▏ 4.5 GB/4.7 GB  157 MB/s      1spulling manifest
# pulling 2bada8a74506...  95% ▕▏ 4.5 GB/4.7 GB  157 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  157 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  157 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  96% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  138 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.5 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.6 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.6 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.6 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.6 GB/4.7 GB  118 MB/s      1spulling manifest
# pulling 2bada8a74506...  97% ▕▏ 4.6 GB/4.7 GB  118 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  122 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  98% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB  117 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.6 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   86 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506...  99% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   58 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB/4.7 GB   53 MB/s      0spulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b...   0% ▕▏    0 B/  68 B                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b...   0% ▕▏    0 B/  68 B                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78...   0% ▕▏    0 B/1.5 KB                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78...   0% ▕▏    0 B/1.5 KB                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68...   0% ▕▏    0 B/ 11 KB                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68...   0% ▕▏    0 B/ 11 KB                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05...   0% ▕▏    0 B/ 487 B                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05...   0% ▕▏    0 B/ 487 B                  pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B                         pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# ...
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2bada8a74506... 100% ▕▏ 4.7 GB
# pulling 66b9ea09bd5b... 100% ▕▏   68 B
# pulling eb4402837c78... 100% ▕▏ 1.5 KB
# pulling 832dd9e00a68... 100% ▕▏  11 KB
# pulling 2f15b3218f05... 100% ▕▏  487 B
# verifying sha256 digest
# writing manifest
# success
# NAME                   ID              SIZE      MODIFIED
# qwen2.5:7b             845dbda0ea48    4.7 GB    Less than a second ago
# llama3.2-vision:11b    085a1fdae525    7.9 GB    27 minutes ago

# %% [markdown]
# ## Docling

# %%
# !pip install docling==2.7.0
# Out:
# Requirement already satisfied: docling==2.7.0 in /usr/local/lib/python3.11/dist-packages (2.7.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (4.12.3)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2024.12.14)
# Requirement already satisfied: deepsearch-glm<0.27.0,>=0.26.1 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (0.26.2)
# Requirement already satisfied: docling-core<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.14.0)
# Requirement already satisfied: docling-ibm-models<3.0.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.0.8)
# Requirement already satisfied: docling-parse<3.0.0,>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.1.2)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (0.27.1)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.1.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (3.1.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.2.2)
# Requirement already satisfied: pyarrow<17.0.0,>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (16.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.10.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.7.1)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (4.30.1)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (2.32.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (1.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (1.13.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in /usr/local/lib/python3.11/dist-packages (from docling==2.7.0) (0.12.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling==2.7.0) (2.6)
# Requirement already satisfied: docutils!=0.21 in /usr/local/lib/python3.11/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (0.21.2)
# Requirement already satisfied: numpy<3.0.0,>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (1.26.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (1.0.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /usr/local/lib/python3.11/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (13.9.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (4.67.1)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from docling-core<3.0.0,>=2.4.0->docling==2.7.0) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.11/dist-packages (from docling-core<3.0.0,>=2.4.0->docling==2.7.0) (4.23.0)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from docling-core<3.0.0,>=2.4.0->docling==2.7.0) (10.4.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1 in /usr/local/lib/python3.11/dist-packages (from docling-core<3.0.0,>=2.4.0->docling==2.7.0) (6.0.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from docling-core<3.0.0,>=2.4.0->docling==2.7.0) (4.12.2)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (3.1.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /usr/local/lib/python3.11/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (4.10.0.84)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (2.5.1+cu121)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.11/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (0.20.1+cu121)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling==2.7.0) (0.25.0)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling==2.7.0) (0.6.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling==2.7.0) (2.0.6)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling==2.7.0) (1.3.0.post6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling==2.7.0) (1.11.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub<1,>=0.23->docling==2.7.0) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub<1,>=0.23->docling==2.7.0) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub<1,>=0.23->docling==2.7.0) (24.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling==2.7.0) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->docling==2.7.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->docling==2.7.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.1.4->docling==2.7.0) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->docling==2.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->docling==2.7.0) (2.27.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx<2.0.0,>=1.1.2->docling==2.7.0) (5.3.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx<2.0.0,>=1.0.2->docling==2.7.0) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->docling==2.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->docling==2.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->docling==2.7.0) (2.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->docling==2.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->docling==2.7.0) (1.5.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.4.0->docling==2.7.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.4.0->docling==2.7.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.4.0->docling==2.7.0) (0.22.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling==2.7.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (1.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.7.0) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.7.0) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.7.0) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling==2.7.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling==2.7.0) (3.0.2)

# %%
from docling_core.types.doc import PictureItem
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions,EasyOcrOptions
from docling.document_converter import DocumentConverter,PdfFormatOption
import time

# %%
pipeline_options = PdfPipelineOptions()

pipeline_options.images_scale = 1
#pipeline_options.generate_page_images = True
#pipeline_options.generate_table_images = True
pipeline_options.do_ocr = True
pipeline_options.do_table_structure = True
pipeline_options.table_structure_options.do_cell_matching = True
ocr_options = EasyOcrOptions(force_full_page_ocr=True)
pipeline_options.ocr_options = ocr_options
pipeline_options.generate_picture_images = True

doc_converter = DocumentConverter(
    format_options={
        InputFormat.IMAGE: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# %%
def Run_Docling(Image_path):
    # Convert the image to Markdown
    start_time = time.time()

    result = doc_converter.convert(Image_path)

    end_time = time.time()

    Markdown = result.document.export_to_markdown()

    Inference_time = end_time - start_time
    return Markdown,Inference_time


import matplotlib.pyplot as plt
import cv2

def Show_image(image_path,size):
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(size, size))
    plt.imshow(img_rgb)
    plt.axis('off')
    #plt.title(image_path)
    plt.show()

# %%
# Example usage
Image_path = "2.jpg"
Show_image(Image_path,16)

# %%
Markdown,Inference_time = Run_Docling(Image_path)
print("Inference Time (s) : ",Inference_time)
print(Markdown)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/3.49k [00:00<?, ?B/s]
# .gitignore:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# (…)artifacts/tableformer/fat/tm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# otslp_all_fast.check:   0%|          | 0.00/146M [00:00<?, ?B/s]
# model.pt:   0%|          | 0.00/202M [00:00<?, ?B/s]
# otslp_all_standard_094_clean.check:   0%|          | 0.00/213M [00:00<?, ?B/s]
# (…)del_artifacts/tableformer/tm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteInference Time (s) :  32.27657675743103
# <!-- image -->
#
# FACTURE N'
#
# FV230007
#
# Date
#
# 13/01/2023
#
# OUTIDIS SARL
#
# 003052404000075
#
# MODE DE REGLEMENT
#
# Page
#
# | REFERENCE   | DESIGNATION                             | QTE   | PU. BRUT   | REM   | PU. NET   | Montant HT   |
# |-------------|-----------------------------------------|-------|------------|-------|-----------|--------------|
# | CV8.5/5KP   | GARTE VISITE 8.5*5.5 R/V                | 400   | 0.75       |       | 0.75      | 300.00       |
# |             | 2 MODELS 200 EXEMPLAIRE                 |       |            |       |           |              |
# | IMVIBRKP    | IMPRESSION SUR VINYL BRILLANT 40*264 CM |       | 105.00     |       | 105.00    | 105.00       |
# | ILOTKP      | CARTE 15*15 SUR PAPIER SPECIAL          | 12    | 7.00       |       | 7.00      | 84.00        |
#
# <!-- image -->
#
# TOTAL HT
#
# ARRETEE LA PRESENTE FACTURE A LA SOMME DE
#
# cent quatre-vingt six Dirhams; quatre-vingts Cts Cinq
#
# TOTAL TVA
#
# TOTAL T.T.C.
#
# 586.80
#
# Le service commercial.
#
# 489.00
#
# 97.80
#
# Délai Livraison
#
# Validité de l'offre

# %% [markdown]
# - You notice that the markdown dosn't countain the Name of the Supplier because Docling here mark it **<!-- image --**
#
# - In the documentation we didn't find any parameter to adjust this behaviour. A possible solution is applying an OCR on these pictures then add the results to the Markdown.

# %% [markdown]
# ### Setup Paddle

# %%
## CPU :
#!pip install paddlepaddle -i https://pypi.tuna.tsinghua.edu.cn/simple
## GPU :
# !pip install paddlepaddle-gpu -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting paddlepaddle-gpu
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/84/5c/8d3aa7503980b9c1e0dafa4bc58fdc5ecadb4424c5eec8262f3159aaef55/paddlepaddle_gpu-2.6.2-cp311-cp311-manylinux1_x86_64.whl (759.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.0/759.0 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (4.4.2)
# Collecting astor (from paddlepaddle-gpu)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle-gpu)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu) (4.25.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.3.1)
# Installing collected packages: opt-einsum, astor, paddlepaddle-gpu
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-gpu-2.6.2

# %%
# !pip install "paddleocr>=2.0.1" # Recommend to use version 2.0.1+
# Out:
# Collecting paddleocr>=2.0.1
#   Downloading paddleocr-2.9.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (0.25.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (0.4.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (1.3.0.post6)
# Collecting lmdb (from paddleocr>=2.0.1)
#   Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (4.67.1)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (1.26.4)
# Collecting rapidfuzz (from paddleocr>=2.0.1)
#   Downloading rapidfuzz-3.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (3.0.11)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (10.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (6.0.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (4.55.3)
# Collecting fire>=0.3.0 (from paddleocr>=2.0.1)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from paddleocr>=2.0.1) (2.32.3)
# Collecting albumentations==1.4.10 (from paddleocr>=2.0.1)
#   Downloading albumentations-1.4.10-py3-none-any.whl.metadata (38 kB)
# Collecting albucore==0.0.13 (from paddleocr>=2.0.1)
#   Downloading albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# Collecting tomli>=2.0.1 (from albucore==0.0.13->paddleocr>=2.0.1)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.6.0)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (2.10.5)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.5.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr>=2.0.1) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr>=2.0.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr>=2.0.1) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr>=2.0.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr>=2.0.1) (0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from imgaug->paddleocr>=2.0.1) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from imgaug->paddleocr>=2.0.1) (3.10.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx->paddleocr>=2.0.1) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr>=2.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr>=2.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr>=2.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr>=2.0.1) (2024.12.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (2.27.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Downloading paddleocr-2.9.1-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 19.9 MB/s eta 0:00:00
# Downloading albucore-0.0.13-py3-none-any.whl (8.5 kB)
# Downloading albumentations-1.4.10-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 16.4 MB/s eta 0:00:00
# Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 28.0 MB/s eta 0:00:00
# Downloading rapidfuzz-3.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.0 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 21.7 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=1e69f39547eba973ff4cbbb5da2bfa2827d296d9d560450c0e59fe91ad402af4
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: lmdb, tomli, rapidfuzz, fire, albucore, albumentations, paddleocr
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# Successfully installed albucore-0.0.13 albumentations-1.4.10 fire-0.7.0 lmdb-1.6.2 paddleocr-2.9.1 rapidfuzz-3.11.0 tomli-2.2.1

# %% [markdown]
# ### Updated function

# %% [markdown]
# For every image detected in the document, the pipeline:
#
# - Saves the image temporarily for processing.
# - Sends the image to PaddleOCR for text extraction.
# - Combines the extracted text from the image with the text content of the document itself.
# - The extracted text is added at the beginning of the markdown.

# %%
from paddleocr import PaddleOCR
paddle_reader = PaddleOCR(use_angle_cls=True, lang='fr')

def Run_Paddle(Image_path):
    Start = time.time()
    result = paddle_reader.ocr(Image_path, det=True, rec=True)
    End = time.time()
    # Inference Time
    Time = End-Start
    # Process the result
    extracted_text = ''
    #print("Lenght Result: ",len(result))
    for line in result:
        if line is not None:
            for word in line:
                #print("Word: ",word)
                # Access the text part of the tuple
                extracted_text += word[1][0] + ' '  # Access the first element of the recognized text (the text itself)
            extracted_text += '\n'
    return extracted_text,Time


def Run_Docling_Updated(Image_path):
    # Convert the image to Markdown
    start_time = time.time()

    result = doc_converter.convert(Image_path)

    Markdown = result.document.export_to_markdown()
    # Itirate over all pictures in the document
    for element, _level in result.document.iterate_items():
        if isinstance(element, PictureItem):
            filename = "Last_Image.jpg"
            #element.image.pil_image.show()
            # Show the Image
            element.image.pil_image.save(filename)
            Show_image(filename,5)

            extracted_text,Time = Run_Paddle(filename)
            Markdown = extracted_text+"\n\n"+ Markdown
    end_time = time.time()
    Inference_time = end_time - start_time
    return Markdown,Inference_time
# Out:
# [2025/01/17 17:40:06] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.11/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='fr', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/17 17:40:06] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/01/17 17:40:07] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/01/17 17:40:07] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0

# %%
Markdown,Inference_time = Run_Docling_Updated(Image_path)
print(f"\n Inference Time (s) : {Inference_time}\n")
print(Markdown)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-82436848851a> in <cell line: 0>()
# ----> 1 Markdown,Inference_time = Run_Docling_Updated(Image_path)
#       2 print(f"\n Inference Time (s) : {Inference_time}\n")
#       3 print(Markdown)
#
# <ipython-input-9-a1a5efbee654> in Run_Docling_Updated(Image_path)
#      34             #element.image.pil_image.show()
#      35             # Show the Image
# ---> 36             Show_image(filename,5)
#      37             element.image.pil_image.save(filename)
#      38             extracted_text,Time = Run_Paddle(filename)
#
# <ipython-input-4-d8f9053a5907> in Show_image(image_path, size)
#      18 def Show_image(image_path,size):
#      19     img = cv2.imread(image_path)
# ---> 20     img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      21     plt.figure(figsize=(size, size))
#      22     plt.imshow(img_rgb)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## LLM

# %% [markdown]
# ### Structered Output

# %% [markdown]
# **Structured output** in LangChain refers to generating text or data in a well-organized and predictable format. This is especially useful when extracting information from documents, performing question-answering tasks, or interacting with large language models (LLMs) where the results need to be machine-readable for further processing.
#
#
#
# **Examples of Use Cases**
#
# 1. **Invoice Data Extraction**:
#    Extract key details from an invoice such as the supplier name, invoice number, dates, and amounts.
#
#    **Structured Output Format (JSON)**:
#    ```json
#    {
#      "Supplier Name": "ABC Supplies",
#      "Invoice Number": "12345",
#      "Invoice Date": "2023-11-20",
#      "Due Date": "2023-12-20",
#      "Items": [
#        {"Name": "Laptop", "Price": "$1000"},
#        {"Name": "Mouse", "Price": "$50"}
#      ],
#      "Total Amount": "$1,050"
#    }
#    ```
#
# ---
#
# 2. **Resume Parsing**:
#    Extract key information from a resume for HR processing.
#
#    **Structured Output Format (JSON)**:
#    ```json
#    {
#      "Name": "John Doe",
#      "Contact Information": {
#        "Email": "johndoe@example.com",
#        "Phone": "+123456789"
#      },
#      "Education": [
#        {"Degree": "BSc Computer Science", "Year": "2020", "Institution": "XYZ University"}
#      ],
#      "Experience": [
#        {"Role": "Software Engineer", "Company": "TechCorp", "Years": "2020-2023"}
#      ],
#      "Skills": ["Python", "Machine Learning", "Docker"]
#    }
#    ```
#
# ---
#
#
#
# **Why Use Structured Output in LangChain?**
#
# - **Improved Automation**: Downstream systems (e.g., databases, workflows) can easily parse structured outputs.
# - **Reliable Parsing**: Formats like JSON are easily parsed programmatically, avoiding ambiguity in freeform text.
# - **Predictable Output**: Ensures uniformity, especially when processing multiple documents or handling repeated queries.
# - **Ease of Integration**: Structured outputs can be directly fed into other tools (e.g., dashboards, APIs, or analysis pipelines).

# %% [markdown]
# <a href = "https://python.langchain.com/docs/how_to/structured_output/">More details in LangChain Docs<a>

# %% [markdown]
# ### Install Dependencies

# %%
# !pip install langchain-openai==0.2.9

# %% [markdown]
# ### Implementation

# %%
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field

class Extraction_Facture(BaseModel):
    """Les Informations principales à extraire a partir d'une facture française"""
    Nom_facture: str = Field("", description="Le nom et le format(.jpg, .png, .jpeg) de l'image de la facture")
    Fournisseur: str = Field("", description="Le nom du fournisseur de la facture")
    date_facture: str = Field("", description="La date de la facture")
    num_facture: str = Field("", description="L'identifiant de la facture, peut être numérique ou alphanumérique")
    ttc: float = Field(0.0, description="Toutes Taxes Comprises. Il s'agit du prix final total payé par le client. Il inclut le prix Total HT et la Total TVA.")
    tt: float = Field(0.0, description="Le total hors taxes de la facture")
    tva: float = Field(0.0, description="Le Total taxes")


system = """
Vous êtes un assistant puissant dans l'extraction d'informations a partir des factures francaises. \n
- Un OCR est appliqué sur l'image de la facture, lire le text et extraire les informations suivantes :  \n

- Fournisseur, Date_Facture, Num_Facture, TTC, TT, TVA \n
- Les 3 prix TT,TTC,TVA doivent être numérique sans indication de devise. \n
- le nom de Fournisseur doit être en majuscule. \n
"""

# %%
## Prompt Template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Le text donné par OCR ici :\n {Parser_Output} \n le Nom de facture est : \n {Nom_facture} \n"),
    ]
)

# %%
from langchain_openai import ChatOpenAI
import pandas as pd
import time

LLM = ChatOpenAI(
    model="qwen2.5:7b",
    #temperature=0,
    api_key='ollama',
    base_url="http://localhost:11434/v1",
)
LLM_Structered = LLM.with_structured_output(Extraction_Facture)
LLM_Extractor = prompt | LLM_Structered

def Run_LLM(Parser_Output, Nom_facture):
    Input = {"Parser_Output":Parser_Output, "Nom_facture":Nom_facture}
    response = LLM_Extractor.invoke(Input)
    return response

# %%
Image_path = "2.jpg"
Markdown,Inference_time = Run_Docling_Updated(Image_path)
print(f"\n Inference Time (s) : {Inference_time}\n")
print(Markdown)

# %%
Input = {"Parser_Output":Markdown, "Nom_facture":Image_path}
response = LLM_Extractor.invoke(Input)
response
# Out:
# Extraction_Facture(Nom_facture='2.jpg', Fournisseur='OUTIDIS SARL', date_facture='13/01/2023', num_facture='FV230007', ttc=586.8, tt=489.0, tva=97.8)

# %% [markdown]
# # Using an OCR + LLM

# %% [markdown]
# ## Setup Ollama :

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh

import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# !ollama pull qwen2.5:7b
# !ollama list

# %% [markdown]
# ## OCR

# %% [markdown]
# ### Setup Paddle

# %%
## CPU :
#!pip install paddlepaddle -i https://pypi.tuna.tsinghua.edu.cn/simple
## GPU :
# !pip install paddlepaddle-gpu -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: paddlepaddle-gpu in /usr/local/lib/python3.10/dist-packages (2.6.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (0.27.2)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.4.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.25.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.2.2)

# %%
# !pip install "paddleocr>=2.0.1" # Recommend to use version 2.0.1+
# Out:
# Requirement already satisfied: paddleocr>=2.0.1 in /usr/local/lib/python3.10/dist-packages (2.9.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.24.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.4.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.3.0.post6)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.66.6)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.26.4)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (3.10.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (3.0.11)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (10.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (6.0.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.55.0)
# Requirement already satisfied: fire>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.32.3)
# Requirement already satisfied: albumentations==1.4.10 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.4.10)
# Requirement already satisfied: albucore==0.0.13 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.0.13)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (2.1.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.5.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (2.9.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.5.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (3.8.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr>=2.0.1) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (2024.8.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (2.23.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)

# %% [markdown]
# ### Paddle

# %%
from paddleocr import PaddleOCR
paddle_reader = PaddleOCR(use_angle_cls=True, lang='fr')

def Run_Paddle(Image_path):
    Start = time.time()
    result = paddle_reader.ocr(Image_path, det=True, rec=True)
    End = time.time()
    # Inference Time
    Time = End-Start
    # Process the result
    extracted_text = ''
    #print("Lenght Result: ",len(result))
    for line in result:
        if line is not None:
            for word in line:
                #print("Word: ",word)
                # Access the text part of the tuple
                extracted_text += word[1][0] + ' '  # Access the first element of the recognized text (the text itself)
            extracted_text += '\n'
    return extracted_text,Time
# Out:
# [2024/11/21 22:52:25] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/latin/latin_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/dict/latin_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='fr', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/11/21 22:52:25] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2024/11/21 22:52:27] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2024/11/21 22:52:29] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0

# %% [markdown]
# ## LLM

# %% [markdown]
# ### Install Dependencies

# %%
# !pip install langchain-openai==0.2.9

# %% [markdown]
# ### Implementation

# %%
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field

class Extraction_Facture(BaseModel):
    """Les Informations principales à extraire a partir d'une facture française"""
    Nom_facture: str = Field("", description="Le nom et le format(.jpg, .png, .jpeg) de l'image de la facture")
    Fournisseur: str = Field("", description="Le nom du fournisseur de la facture")
    date_facture: str = Field("", description="La date de la facture")
    num_facture: str = Field("", description="L'identifiant de la facture, peut être numérique ou alphanumérique")
    ttc: float = Field(0.0, description="Toutes Taxes Comprises. Il s'agit du prix final total payé par le client. Il inclut le prix Total HT et la Total TVA.")
    tt: float = Field(0.0, description="Le total hors taxes de la facture")
    tva: float = Field(0.0, description="Le Total taxes")


system = """
Vous êtes un assistant puissant dans l'extraction d'informations a partir des factures francaises. \n
- Un OCR est appliqué sur l'image de la facture, lire le text et extraire les informations suivantes :  \n

- Fournisseur, Date_Facture, Num_Facture, TTC, TT, TVA \n
- Les 3 prix TT,TTC,TVA doivent être numérique sans indication de devise. \n
- le nom de Fournisseur doit être en majuscule. \n
"""

# %%
## Prompt Template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Le text donné par OCR ici :\n {OCR_Output} \n le Nom de facture est : \n {Nom_facture} \n"),
    ]
)

# %%
from langchain_openai import ChatOpenAI
import pandas as pd
import time

LLM = ChatOpenAI(
    model="qwen2.5:7b",
    #temperature=0,
    api_key='ollama',
    base_url="http://localhost:11434/v1",
)
LLM_Structered = LLM.with_structured_output(Extraction_Facture)
LLM_Extractor = prompt | LLM_Structered

def Run_LLM(Parser_Output, Nom_facture):
    Input = {"OCR_Output":OCR_Output, "Nom_facture":Nom_facture}
    response = LLM_Extractor.invoke(Input)
    return response

# %%
Image_path = "2.jpg"
OCR_Output,Inference_time = Run_Paddle(Image_path)
print(f"\n Inference Time (s) : {Inference_time}\n")
print(OCR_Output)
# Out:
# [2024/11/21 22:53:51] ppocr DEBUG: dt_boxes num : 54, elapsed : 0.08028697967529297
# [2024/11/21 22:53:51] ppocr DEBUG: cls num  : 54, elapsed : 0.08476042747497559
# [2024/11/21 22:53:51] ppocr DEBUG: rec_res num  : 54, elapsed : 0.1887810230255127
#
#  Inference Time (s) : 0.40481019020080566
#
# FACTURE N°: FV230007 KiPRiNT Date  Délai Livraison Validité de I'offre 13/01/2023 BIEN PLUS QU'UNE SIMPLE IMPRESSION OUTIDIS SARL 003052404000075 MODE DE REGLEMENT: Page REFERENCE DESIGNATION QTE P.U. BRUT REM P.U.NET Montant HT CV8.5/5KP CARTE VISITE 8.5*5.5 R/V 400 0.75 0.75 300.00 2 MODELS * 200 EXEMPLAIRE IMVIBRKP IMPRESSION SUR VINYL BRILLANT 40*264 CM 1 105.00 105.00 105.00 ILOTKP CARTE 15*15 SUR PAPIER SPECIAL 12 7.00 7.00 84.00 ue C& TC TOTAL HT TOTAL TVA TOTAL T.T.C. 489.00 97.80 586.80 ARRETEE LA PRESENTE FACTURE A LA SOMME DE : Cinq cent quatre-vingt six Dirhams, quatre-vingts Cts Le service commercial.  44, résidence taiba, lotissement salwan, oulfa, Casablanca - Maroc RC : 514927-N°Patente : 36004690 -N°CNSS :2791157-IF :50522742 -ICE :002891004000053 Tél212522938659/212808607042-E-mail:contact@kiprint.ma

# %%
Input = {"OCR_Output":OCR_Output, "Nom_facture":Image_path}
response = LLM_Extractor.invoke(Input)
response
# Out:
# Extraction_Facture(Nom_facture='2.jpg', Fournisseur='OUTIDIS SARL', date_facture='13/01/2023', num_facture='FV230007', ttc=586.8, tt=489.0, tva=97.8)
